# %% [markdown]
# # Open File
# uxarray Grid object provides a few options to load grid file. Such as:
#
# 1. from_dataset (ux.Grid.from_dataset(GRID_FILENAME, use_dual=True or False))
# 2. open_grid (ux.open_grid(GRID_FILENAME, use_dual=True or False))
# 3. from_file (ux.Grid.from_file(GRID_FILENAME, backend="geopandas" or "xarray"))
#
# This notebook demonstrates to use the from_file function and options.
# File formats such as:
#
# 1. Shapefile
# 2. Geojson
#
#
# and others can be opened using the uxarray Grid classes from_file function.

# %%
import uxarray as ux

# %% [markdown]
# ## Load a shapefile and plot

# %% [markdown]
# 1. Load 5 not connected polygons and plot

# %%
shp_filename = "../../test/meshfiles/shp/multipoly/multipoly.shp"
uxds = ux.Grid.from_file(shp_filename)
print(uxds.node_lat)  # some values are not seen in plots 135+..
uxds.plot(backend="bokeh") # even with matplotlib backend one polygon is missing
# Out:
# Original CRS: None
# Assigned CRS: EPSG:4326
# <xarray.DataArray 'node_lat' (n_node: 31)> Size: 248B
# array([ 40.        ,  35.        ,  45.        ,  15.77350269,
#         10.        ,   4.22649731,  10.        , -30.        ,
#        -35.49092736, -33.39357974, -26.60642026, -24.50907264,
#        145.77350269, 144.0824829 , 140.        , 135.9175171 ,
#        134.22649731, 135.9175171 , 140.        , 144.0824829 ,
#        -10.        , -13.12139121, -15.25176277, -15.71473676,
#        -14.3633222 , -11.62658368,  -8.37341632,  -5.6366778 ,
#         -4.28526324,  -4.74823723,  -6.87860879])
# Dimensions without coordinates: n_node
# Attributes:
#     standard_name:  latitude
#     long name:      Latitude of the corner nodes of each face
#     units:          degrees_north
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
# ...

# %%
import matplotlib.pyplot as plt  # Import Matplotlib

# Assuming uxds.node_lat and uxds.node_lon are available
plt.scatter(uxds.node_lon, uxds.node_lat, marker='o', color='blue')  # Scatter plot
plt.title('Node Locations')  # Title of the plot
plt.xlabel('Longitude')  # X-axis label
plt.ylabel('Latitude')  # Y-axis label
plt.grid(True)  # Enable grid
plt.show()  # Show the plot

# %%
import geopandas as gpd
gdf = gpd.read_file(shp_filename)  # Read the shapefile

# Plot the shapefile
gdf.plot()  # Plot the GeoDataFrame
plt.show()  # Show the plot
