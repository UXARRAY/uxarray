# %%
import uxarray as ux

# %%
mesh_file30 = "/Users/mbook/PyCharmProjects/uxarray/test/meshfiles/outCSne30.ug"
data_file30 = "/Users/mbook/PyCharmProjects/uxarray/test/meshfiles/outCSne30_vortex.nc"
data_file30_v2 = "/Users/mbook/PyCharmProjects/uxarray/test/meshfiles/outCSne30_var2.ug"

# %%
uds = ux.open_dataset(mesh_file30, data_file30, data_file30_v2)

# %%
uds.ds
# Out:
# <xarray.Dataset>
# Dimensions:           (nMesh2_face: 5400, nMaxMesh2_face_nodes: 4,
#                        nMesh2_node: 5402, ncol: 5400)
# Coordinates:
#     Mesh2_node_x      (nMesh2_node) float64 ...
#     Mesh2_node_y      (nMesh2_node) float64 ...
# Dimensions without coordinates: nMesh2_face, nMaxMesh2_face_nodes, nMesh2_node,
#                                 ncol
# Data variables:
#     Mesh2             int32 ...
#     Mesh2_face_nodes  (nMesh2_face, nMaxMesh2_face_nodes) int32 ...
#     psi               (ncol) float64 dask.array<chunksize=(5400,), meta=np.ndarray>
#     var2              (ncol) float64 dask.array<chunksize=(5400,), meta=np.ndarray>

# %%
time integral_psi = uds.integrate("psi")
# Out:
# CPU times: user 3.21 s, sys: 49.4 ms, total: 3.26 s
# Wall time: 3.29 s

# %%
time integral_var2 = uds.integrate("var2")
# Out:
# CPU times: user 902 µs, sys: 729 µs, total: 1.63 ms
# Wall time: 1.06 ms
