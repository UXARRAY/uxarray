# %%
import uxarray as ux
import hvplot.pandas

from spatialpandas import GeoDataFrame
from shapely import Polygon
import antimeridian
import numpy as np

# %%
# Dataset Path
base_path = "../../test/meshfiles/ugrid/outCSne30/"
grid_path = base_path + "outCSne30.ug"
data_path = base_path + "outCSne30_vortex.nc"
#
# base_path = "../../test/meshfiles/ugrid/geoflow-small/"
# grid_path = base_path + "grid.nc"
# data_path = base_path + "v1.nc"

# %%
uxds = ux.open_dataset(grid_path, data_path)

# %%
uxds
# Out:
# <xarray.UxDataset>
# Dimensions:  (ncol: 5400)
# Dimensions without coordinates: ncol
# Data variables:
#     psi      (ncol) float64 1.351 1.331 1.31 1.289 ... 0.7121 0.6909 0.67 0.6495

# %%
gdf_grid_only = uxds.uxgrid.to_geodataframe()

# %%
gdf_grid_only.hvplot()
# Out:
# :Polygons   [x,y]
# :Polygons   [x,y]

# %%
uxds.uxgrid.polygon_shells[4965]
# Out:
# array([[   0.        ,   90.        ],
#        [  90.        ,   87.        ],
#        [ 135.        ,   85.76122798],
#        [-180.        ,   87.        ],
#        [   0.        ,   90.        ]])
# array([[   0.        ,   90.        ],
#        [  90.        ,   87.        ],
#        [ 135.        ,   85.76122798],
#        [-180.        ,   87.        ],
#        [   0.        ,   90.        ]])

# %%
print(antimeridian.fix_polygon(Polygon(uxds.uxgrid.polygon_shells[4965])))
# Out:
# POLYGON ((-180 90, -180 -90, 180 -90, 180 90, -180 90), (-180 87.00000000000009, -180 87.00000000000009, 0 90, 90 87.00000000000009, 135 85.76122797743554, 180 87.00000000000009, 180 90, -180 90, -180 87.00000000000009))

# %%
for val in uxds.uxgrid.polygon_shells[4965]:
    print(repr(val[0]))
# Out:
# 0.0
# 90.0
# 135.0
# -180.0
# 0.0

# %%
np.isclose(uxds.uxgrid.polygon_shells[4965][3, 0], -180.0)
# Out:
# True

# %%
uxds.uxgrid.polygon_shells[4965][4, 0] == 0
# Out:
# True
